# %%
import pytesseract
import cv2
import matplotlib.pyplot as plt
pytesseract.pytesseract.tesseract_cmd = "C:/Program Files/Tesseract-OCR/tesseract.exe"

# %%
img = cv2.imread('sample1.png')
plt.imshow(img)

# %%
mytext = pytesseract.image_to_string(img)
print(mytext)
# Out:
# This is a lot of 12 point text to test the
# ocr code and see if it works on all types
# of file format,
#
# The quick brown dog jumped over the
# lazy fox. The quick brown dog jumped
# over the lazy fox. The quick brown dog
# jumped over the lazy fox. The quick
# brown dog jumped over the lazy fox

# %%
img = cv2.imread('sample2.jpg')
plt.imshow(img)

# %%
mytext1 = pytesseract.image_to_string(img)
print(mytext1)
# Out:
#
#
# Noisy image
# to test
# Tesseract OCR

# %%
img = cv2.imread('sample5.jpg')
plt.imshow(img)

# %%
mytext2 = pytesseract.image_to_string(img)
print(mytext2)
# Out:
# YOU WILL Es m
# NEVER ‘
# Na a
# OR! ID
#
# inl AG ) oe
# iar

# %%
img = cv2.imread('sample6.png')
plt.imshow(img)

# %%
mytext3 = pytesseract.image_to_string(img)
print(mytext3)
# Out:
# Jur Whe te Sun
# You spread woent th
# and inspire fe
# dust log Eaten you
